# %%
import pandas as pd

# %%
a=pd.read_csv(r"C:\Users\zaina\OneDrive\Desktop\class 10 A.I\Pandas\data.csv")

# %%
a
# Out:
#                     books         authors  written_in
# 0  The Pilgrim’s Progress     John Bunyan        1678
# 1         Robinson Crusoe    Daniel Defoe        1719
# 2      Gulliver’s Travels  Jonathan Swift        1726
# 3      Gulliver’s Travels  Jonathan Swift        1726

# %%
a.rename(columns={'books':'class'})
# Out:
#                     class         authors  written_in
# 0  The Pilgrim’s Progress     John Bunyan        1678
# 1         Robinson Crusoe    Daniel Defoe        1719
# 2      Gulliver’s Travels  Jonathan Swift        1726
# 3      Gulliver’s Travels  Jonathan Swift        1726

# %%
a.rename(columns={'authors':'writer','books':'class'})
# Out:
#                     class          writer  written_in
# 0  The Pilgrim’s Progress     John Bunyan        1678
# 1         Robinson Crusoe    Daniel Defoe        1719
# 2      Gulliver’s Travels  Jonathan Swift        1726
# 3      Gulliver’s Travels  Jonathan Swift        1726

# %%
a.rename(index={3:'4th entery'})
# Out:
#                              books         authors  written_in
# 0           The Pilgrim’s Progress     John Bunyan        1678
# 1                  Robinson Crusoe    Daniel Defoe        1719
# 2               Gulliver’s Travels  Jonathan Swift        1726
# 4th entery      Gulliver’s Travels  Jonathan Swift        1726

# %%
a.rename(index={3:'4th entery',0:'1st entry',2:'3rd entry',1:'2nd entry'})
# Out:
#                              books         authors  written_in
# 1st entry   The Pilgrim’s Progress     John Bunyan        1678
# 2nd entry          Robinson Crusoe    Daniel Defoe        1719
# 3rd entry       Gulliver’s Travels  Jonathan Swift        1726
# 4th entery      Gulliver’s Travels  Jonathan Swift        1726

# %%
a.rename_axis('S.no.',axis='rows').rename_axis('Index',axis='columns')
# Out:
# Index                   books         authors  written_in
# S.no.
# 0      The Pilgrim’s Progress     John Bunyan        1678
# 1             Robinson Crusoe    Daniel Defoe        1719
# 2          Gulliver’s Travels  Jonathan Swift        1726
# 3          Gulliver’s Travels  Jonathan Swift        1726

# %%
a.rename_axis('entries',axis='rows').rename_axis('--->',axis='columns')
# Out:
# --->                      books         authors  written_in
# entries
# 0        The Pilgrim’s Progress     John Bunyan        1678
# 1               Robinson Crusoe    Daniel Defoe        1719
# 2            Gulliver’s Travels  Jonathan Swift        1726
# 3            Gulliver’s Travels  Jonathan Swift        1726

# %%
b=pd.read_csv(r"C:\Users\zaina\OneDrive\Desktop\class 10 A.I\Pandas\file.csv")
c=pd.read_csv(r"C:\Users\zaina\OneDrive\Desktop\class 10 A.I\Pandas\file1.csv")

# %%
b
# Out:
#          Indian_Cities   Indian_States  Population Main_Language
# 0               Mumbai     Maharashtra    12442373      Marathi
# 1                Delhi           Delhi    16787941        Hindi
# 2            Bangalore       Karnataka     8443675      Kannada
# 3            Hyderabad       Telangana     6731790       Telugu
# 4            Ahmedabad         Gujarat     5577940     Gujarati
# 5               Chenna      Tamil Nadu     4646732        Tamil
# 6              Kolkata     West Bengal     4496694      Bengali
# 7                Surat         Gujarat     4467797     Gujarati
# 8                 Pune     Maharashtra     3124458      Marathi
# 9               Jaipur       Rajasthan     3046163    Rajasthani
# 10             Lucknow   Uttar Pradesh     2817105        Hindi
# 11              Kanpur   Uttar Pradesh      265348        Hindi
# 12              Nagpur     Maharashtra     2405665      Marathi
# 13              Indore  Madhya Pradesh      164086        Hindi
# ...

# %%
c
# Out:
#            Country  Total_Medals  Gold  Silver  Bronze  Population
# 0    United States          2980  1180     959     841   338289857
# 1   United Kingdom           948   296     320     332    67508936
# 2          Germany           892   293     293     306    83369843
# 3           France           874   258     289     327    64626628
# 4            Italy           742   257     224     261    59037474
# 5            China           696   275     227     194  1425887337
# 6           Sweden           661   205     222     234    10549347
# 7        Australia           562   169     178     215    26177413
# 8            Japan           555   183     172     200   123951692
# 9           Russia           547   196     164     187   144713314
# 10          Norway           528   192     176     160     5434319
# 11          Canada           525   144     172     209    38454327
# 12         Hungary           518   182     156     180     9967308
# ...

# %%
d=pd.concat([b,c])

# %%
d
# Out:
#          Indian_Cities   Indian_States  Population Main_Language  \
# 0               Mumbai     Maharashtra    12442373      Marathi
# 1                Delhi           Delhi    16787941        Hindi
# 2            Bangalore       Karnataka     8443675      Kannada
# 3            Hyderabad       Telangana     6731790       Telugu
# 4            Ahmedabad         Gujarat     5577940     Gujarati
# 5               Chenna      Tamil Nadu     4646732        Tamil
# 6              Kolkata     West Bengal     4496694      Bengali
# 7                Surat         Gujarat     4467797     Gujarati
# 8                 Pune     Maharashtra     3124458      Marathi
# 9               Jaipur       Rajasthan     3046163    Rajasthani
# 10             Lucknow   Uttar Pradesh     2817105        Hindi
# 11              Kanpur   Uttar Pradesh      265348        Hindi
# 12              Nagpur     Maharashtra     2405665      Marathi
# 13              Indore  Madhya Pradesh      164086        Hindi
# ...

# %%
b.shape
# Out:
# (30, 4)

# %%
c.shape
# Out:
# (24, 6)

# %%
d.shape
# Out:
# (54, 9)

# %%
e=pd.concat([b,c],axis=1)

# %%
e
# Out:
#          Indian_Cities   Indian_States  Population Main_Language  \
# 0               Mumbai     Maharashtra    12442373      Marathi
# 1                Delhi           Delhi    16787941        Hindi
# 2            Bangalore       Karnataka     8443675      Kannada
# 3            Hyderabad       Telangana     6731790       Telugu
# 4            Ahmedabad         Gujarat     5577940     Gujarati
# 5               Chenna      Tamil Nadu     4646732        Tamil
# 6              Kolkata     West Bengal     4496694      Bengali
# 7                Surat         Gujarat     4467797     Gujarati
# 8                 Pune     Maharashtra     3124458      Marathi
# 9               Jaipur       Rajasthan     3046163    Rajasthani
# 10             Lucknow   Uttar Pradesh     2817105        Hindi
# 11              Kanpur   Uttar Pradesh      265348        Hindi
# 12              Nagpur     Maharashtra     2405665      Marathi
# 13              Indore  Madhya Pradesh      164086        Hindi
# ...

# %%
b.shape
# Out:
# (30, 4)

# %%
c.shape
# Out:
# (24, 6)

# %%
e.shape
# Out:
# (30, 10)

# %%
f=pd.concat([c,d])

# %%
f
# Out:
#            Country  Total_Medals    Gold  Silver  Bronze  Population  \
# 0    United States        2980.0  1180.0   959.0   841.0   338289857
# 1   United Kingdom         948.0   296.0   320.0   332.0    67508936
# 2          Germany         892.0   293.0   293.0   306.0    83369843
# 3           France         874.0   258.0   289.0   327.0    64626628
# 4            Italy         742.0   257.0   224.0   261.0    59037474
# ..             ...           ...     ...     ...     ...         ...
# 19         Romania         309.0    90.0    97.0   122.0    19659267
# 20            Cuba         241.0    85.0    71.0    85.0    11212191
# 21        Bulgaria         230.0    55.0    90.0    85.0     6781953
# 22         Denmark         206.0    48.0    79.0    79.0     5882261
# 23           Spain         171.0    49.0    72.0    50.0    47558630
#
#    Indian_Cities Indian_States Main_Language
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# ...

# %%
d.shape
# Out:
# (54, 9)

# %%
c.shape
# Out:
# (24, 6)

# %%
f.shape
# Out:
# (78, 9)

# %%
g=pd.concat([e,b],axis=1)

# %%
g
# Out:
#          Indian_Cities   Indian_States  Population Main_Language  \
# 0               Mumbai     Maharashtra    12442373      Marathi
# 1                Delhi           Delhi    16787941        Hindi
# 2            Bangalore       Karnataka     8443675      Kannada
# 3            Hyderabad       Telangana     6731790       Telugu
# 4            Ahmedabad         Gujarat     5577940     Gujarati
# 5               Chenna      Tamil Nadu     4646732        Tamil
# 6              Kolkata     West Bengal     4496694      Bengali
# 7                Surat         Gujarat     4467797     Gujarati
# 8                 Pune     Maharashtra     3124458      Marathi
# 9               Jaipur       Rajasthan     3046163    Rajasthani
# 10             Lucknow   Uttar Pradesh     2817105        Hindi
# 11              Kanpur   Uttar Pradesh      265348        Hindi
# 12              Nagpur     Maharashtra     2405665      Marathi
# 13              Indore  Madhya Pradesh      164086        Hindi
# ...

# %%
e.shape
# Out:
# (30, 10)

# %%
b.shape
# Out:
# (30, 4)

# %%
g.shape
# Out:
# (30, 14)
