# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\zaina\OneDrive\Desktop\class 10 A.I\Pandas\file.csv")

# %%
data
# Out:
#          Indian Cities   Indian States  Population Main Language
# 0               Mumbai     Maharashtra    12442373      Marathi
# 1                Delhi           Delhi    16787941        Hindi
# 2            Bangalore       Karnataka     8443675      Kannada
# 3            Hyderabad       Telangana     6731790       Telugu
# 4            Ahmedabad         Gujarat     5577940     Gujarati
# 5               Chenna      Tamil Nadu     4646732        Tamil
# 6              Kolkata     West Bengal     4496694      Bengali
# 7                Surat         Gujarat     4467797     Gujarati
# 8                 Pune     Maharashtra     3124458      Marathi
# 9               Jaipur       Rajasthan     3046163    Rajasthani
# 10             Lucknow   Uttar Pradesh     2817105        Hindi
# 11              Kanpur   Uttar Pradesh      265348        Hindi
# 12              Nagpur     Maharashtra     2405665      Marathi
# 13              Indore  Madhya Pradesh      164086        Hindi
# ...

# %%
data.Population
# Out:
# 0     12442373
# 1     16787941
# 2      8443675
# 3      6731790
# 4      5577940
# 5      4646732
# 6      4496694
# 7      4467797
# 8      3124458
# 9      3046163
# 10     2817105
# 11      265348
# 12     2405665
# 13      164086
# 14     1841448
# 15     1798218
# 16      128128
# 17     3124458
# 18     1684222
# 19      170806
# 20     1648643
# 21     1618879
# 22      185704
# 23     1486053
# 24     1594839
# 25      105429
# 26     1286678
# 27     1246381
# 28     1222390
# 29     1198491
# Name: Population, dtype: int64

# %%
data['Indian Cities']
# Out:
# 0                 Mumbai
# 1                  Delhi
# 2              Bangalore
# 3              Hyderabad
# 4              Ahmedabad
# 5                 Chenna
# 6                Kolkata
# 7                  Surat
# 8                   Pune
# 9                 Jaipur
# 10               Lucknow
# 11                Kanpur
# 12                Nagpur
# 13                Indore
# 14                 Thane
# 15                Bhopal
# 16         Visakhapatnam
# 17    Pimpri & Chinchwad
# 18                 Patna
# 19              Vadodara
# 20             Ghaziabad
# 21              Ludhiana
# 22                  Agra
# 23                Nashik
# 24             Faridabad
# 25                Meerut
# 26                Rajkot
# 27    Kalyan & Dombivali
# 28           Vasai Virar
# 29              Varanasi
# Name: Indian Cities, dtype: object

# %%
data['Indian States'][3]
# Out:
# 'Telangana'

# %%
data.loc[3]
# Out:
# Indian Cities    Hyderabad
# Indian States    Telangana
# Population         6731790
# Main Language      Telugu
# Name: 3, dtype: object

# %%
data.iloc[0]
# Out:
# Indian Cities         Mumbai
# Indian States    Maharashtra
# Population          12442373
# Main Language       Marathi
# Name: 0, dtype: object

# %%
data.loc[1,'Main Language']
# Out:
# 'Hindi '

# %%
data.iloc[1][0]
# Out:
# 'Delhi'

# %%
data.loc[0:2]
# Out:
#   Indian Cities Indian States  Population Main Language
# 0        Mumbai   Maharashtra    12442373      Marathi
# 1         Delhi         Delhi    16787941        Hindi
# 2     Bangalore     Karnataka     8443675      Kannada

# %%
data.iloc[0:2]
# Out:
#   Indian Cities Indian States  Population Main Language
# 0        Mumbai   Maharashtra    12442373      Marathi
# 1         Delhi         Delhi    16787941        Hindi

# %%
data.iloc[:3,2]
# Out:
# 0    12442373
# 1    16787941
# 2     8443675
# Name: Population, dtype: int64

# %%
data.iloc[-1]
# Out:
# Indian Cities         Varanasi
# Indian States    Uttar Pradesh
# Population             1198491
# Main Language         Bhojpuri
# Name: 29, dtype: object

# %%
data.iloc[-4]
# Out:
# Indian Cities       Rajkot
# Indian States      Gujarat
# Population         1286678
# Main Language    Gujarati
# Name: 26, dtype: object

# %%
data.iloc[-4][2]
# Out:
# 1286678

# %%
data.iloc[[0,3,1],2]
# Out:
# 0    12442373
# 3     6731790
# 1    16787941
# Name: Population, dtype: int64

# %%
data.loc[:,'Population']
# Out:
# 0     12442373
# 1     16787941
# 2      8443675
# 3      6731790
# 4      5577940
# 5      4646732
# 6      4496694
# 7      4467797
# 8      3124458
# 9      3046163
# 10     2817105
# 11      265348
# 12     2405665
# 13      164086
# 14     1841448
# 15     1798218
# 16      128128
# 17     3124458
# 18     1684222
# 19      170806
# 20     1648643
# 21     1618879
# 22      185704
# 23     1486053
# 24     1594839
# 25      105429
# 26     1286678
# 27     1246381
# 28     1222390
# 29     1198491
# Name: Population, dtype: int64

# %%
data.iloc[:,2]
# Out:
# 0     12442373
# 1     16787941
# 2      8443675
# 3      6731790
# 4      5577940
# 5      4646732
# 6      4496694
# 7      4467797
# 8      3124458
# 9      3046163
# 10     2817105
# 11      265348
# 12     2405665
# 13      164086
# 14     1841448
# 15     1798218
# 16      128128
# 17     3124458
# 18     1684222
# 19      170806
# 20     1648643
# 21     1618879
# 22      185704
# 23     1486053
# 24     1594839
# 25      105429
# 26     1286678
# 27     1246381
# 28     1222390
# 29     1198491
# Name: Population, dtype: int64

# %%
data.set_index('Indian States')
# Out:
#                      Indian Cities  Population Main Language
# Indian States
# Maharashtra                 Mumbai    12442373      Marathi
# Delhi                        Delhi    16787941        Hindi
# Karnataka                Bangalore     8443675      Kannada
# Telangana                Hyderabad     6731790       Telugu
# Gujarat                  Ahmedabad     5577940     Gujarati
# Tamil Nadu                  Chenna     4646732        Tamil
# West Bengal                Kolkata     4496694      Bengali
# Gujarat                      Surat     4467797     Gujarati
# Maharashtra                   Pune     3124458      Marathi
# Rajasthan                   Jaipur     3046163    Rajasthani
# Uttar Pradesh              Lucknow     2817105        Hindi
# Uttar Pradesh               Kanpur      265348        Hindi
# Maharashtra                 Nagpur     2405665      Marathi
# Madhya Pradesh              Indore      164086        Hindi
# ...

# %%
data.set_index("Population")
# Out:
#                  Indian Cities   Indian States Main Language
# Population
# 12442373                Mumbai     Maharashtra      Marathi
# 16787941                 Delhi           Delhi        Hindi
# 8443675              Bangalore       Karnataka      Kannada
# 6731790              Hyderabad       Telangana       Telugu
# 5577940              Ahmedabad         Gujarat     Gujarati
# 4646732                 Chenna      Tamil Nadu        Tamil
# 4496694                Kolkata     West Bengal      Bengali
# 4467797                  Surat         Gujarat     Gujarati
# 3124458                   Pune     Maharashtra      Marathi
# 3046163                 Jaipur       Rajasthan    Rajasthani
# 2817105                Lucknow   Uttar Pradesh        Hindi
# 265348                  Kanpur   Uttar Pradesh        Hindi
# 2405665                 Nagpur     Maharashtra      Marathi
# 164086                  Indore  Madhya Pradesh        Hindi
# ...

# %%
data.iloc[[9,10,11,12,13,14,15],1]
# Out:
# 9          Rajasthan
# 10     Uttar Pradesh
# 11     Uttar Pradesh
# 12       Maharashtra
# 13    Madhya Pradesh
# 14       Maharashtra
# 15    Madhya Pradesh
# Name: Indian States, dtype: object
